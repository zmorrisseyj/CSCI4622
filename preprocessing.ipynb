# %%
import csv
import math
import pickle
import gzip
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
# populations = []
# with open("./data/populations.csv", 'r', encoding="utf8") as csvfile: #get edges into networkx graph
#     csvreader = csv.reader(csvfile)
#     for row in csvreader:
#         populations.append(row)
# print(populations)

# ^^^ reads data in as list



pops  = pd.read_csv("./data/populations.csv", encoding='UTF-8') #reads in as pandas dataframe
areas = pd.read_csv("./data/areasqmi.csv", encoding='UTF-8') #reads in as pandas dataframe
mips  = pd.read_csv("./data/mipreport.csv", encoding='UTF-8') #reads in as pandas dataframe
vaccs = pd.read_csv("./data/CDPHE_COVID19_Vaccine_Daily_Summary_Statistics.csv", encoding='UTF-8') #reads in as pandas dataframe
lices = pd.read_csv("./data/liqlicences.csv", encoding='UTF-8')

print("{}\n{}\n{}\n{}\n{}".format(pops,areas,mips,vaccs,lices))
# Out:
#     Rank     County  Population
# 0      1     Denver      705576
# 1      2    El Paso      698974
# 2      3   Arapahoe      644560
# 3      4  Jefferson      574798
# 4      5      Adams      504108
# ..   ...        ...         ...
# 59    60      Kiowa        1489
# 60    61    Jackson        1261
# 61    62   Hinsdale         857
# 62    63    Mineral         824
# 63    64   San Juan         589
#
# [64 rows x 3 columns]
#         County    Value
# 0        Adams  1167.65
# 1      Alamosa   722.64
# 2     Arapahoe   798.10
# 3    Archuleta  1350.18
# 4         Baca  2554.97
# ..         ...      ...
# 59      Summit   608.36
# 60      Teller   557.06
# 61  Washington  2518.03
# 62        Weld  3987.24
# 63        Yuma  2364.41
#
# [64 rows x 2 columns]
#            Date                              Agency  Gender  Quantity  Age  \
# 0    03/01/2020           Windsor Police Department    male         1   16
# ...
